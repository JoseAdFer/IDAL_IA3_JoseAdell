# %% [markdown]
# <a href="https://colab.research.google.com/github/JoseAdFer/IDAL_IA3_JoseAdell/blob/main/dnn_mnist.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Entrenamiento de un Perceptrón Multi-Capa con datos de dígitos (MNIST)

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.layers import Dense, BatchNormalization, Dropout
import matplotlib.pyplot as plt
tf.random.set_seed(42)

# %% [markdown]
# ## Carga de los datos
# #### Tamaño del conjunto de entrenamiento y de test

# %%
(X_train, y_train), (X_test, y_test) = tf.keras.datasets.mnist.load_data()

print(' -Entradas Entrenamiento:', X_train.shape)
print(' -Salidas Entrenamiento:', y_train.shape)
print(' -Entradas Test:', X_test.shape)
print(' -Salidas Test:', y_test.shape)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11493376/11490434 [==============================] - 0s 0us/step
# 11501568/11490434 [==============================] - 0s 0us/step
#  -Entradas Entrenamiento: (60000, 28, 28)
#  -Salidas Entrenamiento: (60000,)
#  -Entradas Test: (10000, 28, 28)
#  -Salidas Test: (10000,)

# %% [markdown]
# #### Visualización de las entradas

# %%
n_img_show = 3

# Plot images
plt.figure(figsize=(16,10))
for i in range(n_img_show):
    plt.subplot(1, n_img_show, i+1)
    plt.imshow(X_train[i], cmap='gray')
    plt.colorbar(fraction=0.046)
    plt.axis('off');

print(f'Valores de salida correspondientes a las imágenes de entrada {y_train[0:n_img_show]}')
# Out:
# Valores de salida correspondientes a las imágenes de entrada [5 0 4]

# %% [markdown]
# ## Preparación de los datos
# #### Normalización

# %%
# Normalizamos a valores entre 0 y 1
X_train = X_train.astype('float32')/255
X_test = X_test.astype('float32')/255

plt.figure(figsize=(16,10))
for i in range(n_img_show):
    plt.subplot(1, n_img_show, i+1)
    plt.imshow(X_train[i], cmap='gray')
    plt.colorbar(fraction=0.046)
    plt.axis('off');

# %% [markdown]
# #### Reajuste del tamaño de la entrada y la salida

# %%
x_shape = X_train.shape
X_train = X_train.reshape(x_shape[0], x_shape[1]*x_shape[2])
X_test = X_test.reshape(len(X_test), x_shape[1]*x_shape[2])
y_train = y_train[:, None]
y_test = y_test[:, None]

# Dibujar la nueva entrada
plt.figure(figsize=(20, 70))
plt.imshow(X_train[0:100], cmap='gray')
plt.xlabel('# Pixeles')
plt.ylabel('# Imágenes')
plt.colorbar(fraction=0.006);

# %% [markdown]
# ## Definición del modelo
# Crea un modelo con las siguientes capas:
# 1. Capa de entrada con tantas entradas como número de píxeles (728)
# 2. Capa oculta con 256 neuronas
# 3. Capa oculta con 128 neuronas
# 4. Capa oculta con 64 neuronas
# 5. Capa oculta con 32 neuronas
# 6. Capa de salidad con tantas neuronas como salidas (10)
#
# Todas las capas usan función de activación relu (menos la de salida). ¿Qué función de activación hay que poner a la salida?

# %%
# Algunos hiper-parámetros
lr = .001
batch_size = 512
n_epochs = 35
optimizer = tf.keras.optimizers.Adam(learning_rate=lr)

# Crear modelo
model=tf.keras.Sequential()
model.add(tf.keras.layers.Dense(256, input_shape=(784,),activation='relu'))
model.add(tf.keras.layers.Dense(128,activation='relu'))
model.add(tf.keras.layers.Dense(64,activation='relu'))
model.add(tf.keras.layers.Dense(32,activation='relu'))
model.add(tf.keras.layers.Dense(10,activation='softmax'))
# Visualizar arquitectura y dimensiones
model.summary()

# Compilamos el modelo: ¿Qué función de coste hay que utilizar?
model.compile(loss='sparse_categorical_crossentropy',
              optimizer=optimizer,
              metrics=['accuracy'])
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_12 (Dense)            (None, 256)               200960
#
#  dense_13 (Dense)            (None, 128)               32896
#
#  dense_14 (Dense)            (None, 64)                8256
#
#  dense_15 (Dense)            (None, 32)                2080
#
#  dense_16 (Dense)            (None, 10)                330
#
# =================================================================
# Total params: 244,522
# Trainable params: 244,522
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## Entrenamiento del modelo

# %%
hist = model.fit(X_train, 
                 y_train, 
                 batch_size=batch_size, 
                 epochs=n_epochs, 
                 verbose=1, 
                 shuffle=True,
                 validation_data=(X_test, y_test))
# Out:
# Epoch 1/35
# 118/118 [==============================] - 3s 19ms/step - loss: 0.5182 - accuracy: 0.8475 - val_loss: 0.2009 - val_accuracy: 0.9410
# Epoch 2/35
# 118/118 [==============================] - 2s 17ms/step - loss: 0.1635 - accuracy: 0.9521 - val_loss: 0.1330 - val_accuracy: 0.9608
# Epoch 3/35
# 118/118 [==============================] - 2s 17ms/step - loss: 0.1133 - accuracy: 0.9665 - val_loss: 0.1071 - val_accuracy: 0.9653
# Epoch 4/35
# 118/118 [==============================] - 2s 17ms/step - loss: 0.0825 - accuracy: 0.9755 - val_loss: 0.0970 - val_accuracy: 0.9721
# Epoch 5/35
# 118/118 [==============================] - 2s 17ms/step - loss: 0.0665 - accuracy: 0.9794 - val_loss: 0.0889 - val_accuracy: 0.9725
# Epoch 6/35
# 118/118 [==============================] - 2s 18ms/step - loss: 0.0539 - accuracy: 0.9840 - val_loss: 0.0791 - val_accuracy: 0.9770
# Epoch 7/35
# 118/118 [==============================] - 2s 17ms/step - loss: 0.0400 - accuracy: 0.9880 - val_loss: 0.0828 - val_accuracy: 0.9747
# Epoch 8/35
# 118/118 [==============================] - 2s 17ms/step - loss: 0.0341 - accuracy: 0.9895 - val_loss: 0.0788 - val_accuracy: 0.9771
# Epoch 9/35
# 118/118 [==============================] - 2s 17ms/step - loss: 0.0259 - accuracy: 0.9922 - val_loss: 0.0787 - val_accuracy: 0.9782
# Epoch 10/35
# 118/118 [==============================] - 2s 17ms/step - loss: 0.0214 - accuracy: 0.9934 - val_loss: 0.0826 - val_accuracy: 0.9756
# Epoch 11/35
# 118/118 [==============================] - 2s 18ms/step - loss: 0.0182 - accuracy: 0.9946 - val_loss: 0.0772 - val_accuracy: 0.9796
# Epoch 12/35
# 118/118 [==============================] - 2s 17ms/step - loss: 0.0172 - accuracy: 0.9947 - val_loss: 0.0799 - val_accuracy: 0.9791
# Epoch 13/35
# 118/118 [==============================] - 2s 17ms/step - loss: 0.0112 - accuracy: 0.9970 - val_loss: 0.0791 - val_accuracy: 0.9797
# Epoch 14/35
# 118/118 [==============================] - 2s 17ms/step - loss: 0.0101 - accuracy: 0.9970 - val_loss: 0.0966 - val_accuracy: 0.9765
# Epoch 15/35
# 118/118 [==============================] - 2s 17ms/step - loss: 0.0122 - accuracy: 0.9963 - val_loss: 0.0905 - val_accuracy: 0.9785
# Epoch 16/35
# 118/118 [==============================] - 2s 17ms/step - loss: 0.0074 - accuracy: 0.9980 - val_loss: 0.0947 - val_accuracy: 0.9780
# Epoch 17/35
# 118/118 [==============================] - 2s 18ms/step - loss: 0.0080 - accuracy: 0.9976 - val_loss: 0.0925 - val_accuracy: 0.9783
# Epoch 18/35
# 118/118 [==============================] - 2s 17ms/step - loss: 0.0127 - accuracy: 0.9957 - val_loss: 0.1044 - val_accuracy: 0.9739
# Epoch 19/35
# 118/118 [==============================] - 2s 17ms/step - loss: 0.0081 - accuracy: 0.9975 - val_loss: 0.0913 - val_accuracy: 0.9806
# Epoch 20/35
# 118/118 [==============================] - 2s 17ms/step - loss: 0.0074 - accuracy: 0.9976 - val_loss: 0.0935 - val_accuracy: 0.9783
# Epoch 21/35
# 118/118 [==============================] - 2s 17ms/step - loss: 0.0032 - accuracy: 0.9992 - val_loss: 0.0948 - val_accuracy: 0.9801
# Epoch 22/35
# 118/118 [==============================] - 2s 18ms/step - loss: 0.0032 - accuracy: 0.9991 - val_loss: 0.0991 - val_accuracy: 0.9800
# Epoch 23/35
# 118/118 [==============================] - 2s 18ms/step - loss: 0.0031 - accuracy: 0.9991 - val_loss: 0.1173 - val_accuracy: 0.9763
# Epoch 24/35
# 118/118 [==============================] - 2s 18ms/step - loss: 0.0142 - accuracy: 0.9953 - val_loss: 0.1068 - val_accuracy: 0.9751
# Epoch 25/35
# 118/118 [==============================] - 2s 17ms/step - loss: 0.0101 - accuracy: 0.9967 - val_loss: 0.0972 - val_accuracy: 0.9793
# Epoch 26/35
# 118/118 [==============================] - 2s 17ms/step - loss: 0.0071 - accuracy: 0.9976 - val_loss: 0.1082 - val_accuracy: 0.9773
# Epoch 27/35
# 118/118 [==============================] - 2s 17ms/step - loss: 0.0036 - accuracy: 0.9990 - val_loss: 0.1056 - val_accuracy: 0.9804
# Epoch 28/35
# 118/118 [==============================] - 2s 17ms/step - loss: 0.0019 - accuracy: 0.9995 - val_loss: 0.0882 - val_accuracy: 0.9826
# Epoch 29/35
# 118/118 [==============================] - 2s 17ms/step - loss: 3.8953e-04 - accuracy: 1.0000 - val_loss: 0.0932 - val_accuracy: 0.9828
# Epoch 30/35
# 118/118 [==============================] - 2s 17ms/step - loss: 1.7033e-04 - accuracy: 1.0000 - val_loss: 0.0939 - val_accuracy: 0.9827
# Epoch 31/35
# 118/118 [==============================] - 2s 17ms/step - loss: 1.1858e-04 - accuracy: 1.0000 - val_loss: 0.0959 - val_accuracy: 0.9826
# Epoch 32/35
# 118/118 [==============================] - 2s 18ms/step - loss: 9.8031e-05 - accuracy: 1.0000 - val_loss: 0.0963 - val_accuracy: 0.9829
# Epoch 33/35
# 118/118 [==============================] - 2s 17ms/step - loss: 8.5054e-05 - accuracy: 1.0000 - val_loss: 0.0979 - val_accuracy: 0.9825
# Epoch 34/35
# 118/118 [==============================] - 2s 17ms/step - loss: 7.7979e-05 - accuracy: 1.0000 - val_loss: 0.0988 - val_accuracy: 0.9827
# Epoch 35/35
# 118/118 [==============================] - 2s 17ms/step - loss: 6.8032e-05 - accuracy: 1.0000 - val_loss: 0.0998 - val_accuracy: 0.9823

# %% [markdown]
# ### Dibujar las curvas de entrenamiento/validación

# %%
def plot_curves(history):
  plt.figure()
  plt.xlabel('Épocas')
  plt.ylabel('Error')
  plt.plot(history['loss'])
  plt.plot(history['val_loss'])
  plt.legend(['Entrenamiento', 'Validación'])

  plt.figure()
  plt.xlabel('Épocas')
  plt.ylabel('Accuracy')
  plt.plot(history['accuracy'])
  plt.plot(history['val_accuracy'])
  plt.legend(['Entrenamiento', 'Validación'], loc='lower right');

plot_curves(hist.history)

# %% [markdown]
# ### Visualización de los pesos

# %%
def plot_weights(model):
  layers = [l for l in model.layers if l.name.startswith('dense')]
  n_img_show = len(layers)
  plt.figure(figsize=(30, 11))
  cnt = 1
  for layer in layers:
      plt.subplot(1, n_img_show, cnt)
      plt.imshow(layer.get_weights()[0])
      plt.title(f'Pesos capa {cnt}')
      plt.colorbar(fraction=0.07)
      cnt += 1

def plot_weights_hist(model):
  layers = [l for l in model.layers if l.name.startswith('dense')]
  n_img_show = len(layers)
  plt.figure(figsize=(30, 5))
  cnt = 1
  for layer in layers:
    if layer.name.startswith('dense'):
      plt.subplot(1, n_img_show, cnt)
      plt.hist(layer.get_weights()[0].flatten(), bins=30)
      plt.title(f'Pesos capa {cnt}')
      mean = np.mean(layer.get_weights()[0])
      std = np.std(layer.get_weights()[0])
      plt.xlabel(f'Valores de los pesos. Media: {mean:.3f} +- {std:.3f}')
      plt.ylabel('cuenta')
      cnt +=1

plot_weights(model)
plot_weights_hist(model)

# %% [markdown]
# ## Regularización del modelo con L2
# Crea un modelo nuevo exactamente igual que el anterior y añade regularización L2 en todas las capas (menos en la de salida, como es obvio). Prueba distintos valores (0.1, 0.01 y 0.001) y observa cual es el comportamiento.

# %%
tf.keras.backend.clear_session()
n_epochs = 50

# Crear modelo
model_with_l2=tf.keras.Sequential()
model_with_l2.add(tf.keras.layers.Dense(256, input_shape=(784,),activation='relu', kernel_regularizer=tf.keras.regularizers.l2(0.01)))
model_with_l2.add(tf.keras.layers.Dense(128,activation='relu',kernel_regularizer=tf.keras.regularizers.l2(0.01)))
model_with_l2.add(tf.keras.layers.Dense(64,activation='relu',kernel_regularizer=tf.keras.regularizers.l2(0.01)))
model_with_l2.add(tf.keras.layers.Dense(32,activation='relu',kernel_regularizer=tf.keras.regularizers.l2(0.01)))
model_with_l2.add(tf.keras.layers.Dense(10,activation='softmax'))
# Compilamos el modelo
model_with_l2.compile(loss='sparse_categorical_crossentropy',
              optimizer=optimizer,
              metrics=['accuracy'])

# Entrenamos
hist = model_with_l2.fit(X_train, 
                         y_train, 
                         batch_size=batch_size, 
                         epochs=n_epochs,
                         verbose=1,
                         shuffle=True, 
                         validation_data=(X_test, y_test))
# Out:
# Epoch 1/50
# 118/118 [==============================] - 3s 19ms/step - loss: 1.6854 - accuracy: 0.8424 - val_loss: 0.9221 - val_accuracy: 0.9038
# Epoch 2/50
# 118/118 [==============================] - 2s 18ms/step - loss: 0.8276 - accuracy: 0.9186 - val_loss: 0.7734 - val_accuracy: 0.9214
# Epoch 3/50
# 118/118 [==============================] - 2s 18ms/step - loss: 0.7348 - accuracy: 0.9280 - val_loss: 0.6942 - val_accuracy: 0.9338
# Epoch 4/50
# 118/118 [==============================] - 2s 19ms/step - loss: 0.6823 - accuracy: 0.9337 - val_loss: 0.7299 - val_accuracy: 0.9093
# Epoch 5/50
# 118/118 [==============================] - 2s 18ms/step - loss: 0.6465 - accuracy: 0.9377 - val_loss: 0.6241 - val_accuracy: 0.9395
# Epoch 6/50
# 118/118 [==============================] - 2s 18ms/step - loss: 0.6163 - accuracy: 0.9403 - val_loss: 0.6340 - val_accuracy: 0.9275
# Epoch 7/50
# 118/118 [==============================] - 2s 18ms/step - loss: 0.5982 - accuracy: 0.9415 - val_loss: 0.5805 - val_accuracy: 0.9417
# Epoch 8/50
# 118/118 [==============================] - 2s 18ms/step - loss: 0.5730 - accuracy: 0.9451 - val_loss: 0.5777 - val_accuracy: 0.9420
# Epoch 9/50
# 118/118 [==============================] - 2s 18ms/step - loss: 0.5628 - accuracy: 0.9443 - val_loss: 0.5442 - val_accuracy: 0.9479
# Epoch 10/50
# 118/118 [==============================] - 2s 18ms/step - loss: 0.5472 - accuracy: 0.9476 - val_loss: 0.5322 - val_accuracy: 0.9491
# Epoch 11/50
# 118/118 [==============================] - 2s 19ms/step - loss: 0.5368 - accuracy: 0.9480 - val_loss: 0.5391 - val_accuracy: 0.9433
# Epoch 12/50
# 118/118 [==============================] - 2s 18ms/step - loss: 0.5281 - accuracy: 0.9497 - val_loss: 0.5168 - val_accuracy: 0.9502
# Epoch 13/50
# 118/118 [==============================] - 2s 19ms/step - loss: 0.5155 - accuracy: 0.9503 - val_loss: 0.5043 - val_accuracy: 0.9514
# Epoch 14/50
# 118/118 [==============================] - 2s 19ms/step - loss: 0.5054 - accuracy: 0.9525 - val_loss: 0.5459 - val_accuracy: 0.9377
# Epoch 15/50
# 118/118 [==============================] - 2s 18ms/step - loss: 0.5023 - accuracy: 0.9517 - val_loss: 0.4866 - val_accuracy: 0.9564
# Epoch 16/50
# 118/118 [==============================] - 2s 19ms/step - loss: 0.4898 - accuracy: 0.9544 - val_loss: 0.4933 - val_accuracy: 0.9530
# Epoch 17/50
# 118/118 [==============================] - 2s 19ms/step - loss: 0.4900 - accuracy: 0.9524 - val_loss: 0.4776 - val_accuracy: 0.9528
# Epoch 18/50
# 118/118 [==============================] - 2s 19ms/step - loss: 0.4806 - accuracy: 0.9537 - val_loss: 0.4696 - val_accuracy: 0.9561
# Epoch 19/50
# 118/118 [==============================] - 2s 18ms/step - loss: 0.4747 - accuracy: 0.9551 - val_loss: 0.4680 - val_accuracy: 0.9562
# Epoch 20/50
# 118/118 [==============================] - 2s 19ms/step - loss: 0.4706 - accuracy: 0.9553 - val_loss: 0.4710 - val_accuracy: 0.9510
# Epoch 21/50
# 118/118 [==============================] - 2s 19ms/step - loss: 0.4656 - accuracy: 0.9560 - val_loss: 0.4623 - val_accuracy: 0.9515
# Epoch 22/50
# 118/118 [==============================] - 2s 18ms/step - loss: 0.4633 - accuracy: 0.9551 - val_loss: 0.4559 - val_accuracy: 0.9562
# Epoch 23/50
# 118/118 [==============================] - 2s 18ms/step - loss: 0.4553 - accuracy: 0.9572 - val_loss: 0.4436 - val_accuracy: 0.9590
# Epoch 24/50
# 118/118 [==============================] - 2s 19ms/step - loss: 0.4506 - accuracy: 0.9573 - val_loss: 0.4429 - val_accuracy: 0.9557
# Epoch 25/50
# 118/118 [==============================] - 2s 18ms/step - loss: 0.4469 - accuracy: 0.9583 - val_loss: 0.4474 - val_accuracy: 0.9549
# Epoch 26/50
# 118/118 [==============================] - 2s 19ms/step - loss: 0.4439 - accuracy: 0.9581 - val_loss: 0.4476 - val_accuracy: 0.9533
# Epoch 27/50
# 118/118 [==============================] - 2s 19ms/step - loss: 0.4423 - accuracy: 0.9570 - val_loss: 0.4296 - val_accuracy: 0.9591
# Epoch 28/50
# 118/118 [==============================] - 2s 19ms/step - loss: 0.4357 - accuracy: 0.9590 - val_loss: 0.4320 - val_accuracy: 0.9589
# Epoch 29/50
# 118/118 [==============================] - 2s 18ms/step - loss: 0.4335 - accuracy: 0.9589 - val_loss: 0.4494 - val_accuracy: 0.9486
# Epoch 30/50
# 118/118 [==============================] - 2s 19ms/step - loss: 0.4306 - accuracy: 0.9588 - val_loss: 0.4330 - val_accuracy: 0.9555
# Epoch 31/50
# 118/118 [==============================] - 2s 18ms/step - loss: 0.4266 - accuracy: 0.9597 - val_loss: 0.4248 - val_accuracy: 0.9590
# Epoch 32/50
# 118/118 [==============================] - 2s 19ms/step - loss: 0.4256 - accuracy: 0.9593 - val_loss: 0.4269 - val_accuracy: 0.9558
# Epoch 33/50
# 118/118 [==============================] - 2s 18ms/step - loss: 0.4188 - accuracy: 0.9609 - val_loss: 0.4264 - val_accuracy: 0.9580
# Epoch 34/50
# 118/118 [==============================] - 2s 19ms/step - loss: 0.4165 - accuracy: 0.9608 - val_loss: 0.4127 - val_accuracy: 0.9604
# Epoch 35/50
# 118/118 [==============================] - 2s 18ms/step - loss: 0.4156 - accuracy: 0.9606 - val_loss: 0.4228 - val_accuracy: 0.9561
# Epoch 36/50
# 118/118 [==============================] - 2s 18ms/step - loss: 0.4165 - accuracy: 0.9595 - val_loss: 0.4212 - val_accuracy: 0.9575
# Epoch 37/50
# 118/118 [==============================] - 2s 19ms/step - loss: 0.4104 - accuracy: 0.9621 - val_loss: 0.4130 - val_accuracy: 0.9573
# Epoch 38/50
# 118/118 [==============================] - 2s 19ms/step - loss: 0.4080 - accuracy: 0.9613 - val_loss: 0.4073 - val_accuracy: 0.9604
# Epoch 39/50
# 118/118 [==============================] - 2s 19ms/step - loss: 0.4076 - accuracy: 0.9610 - val_loss: 0.4035 - val_accuracy: 0.9606
# Epoch 40/50
# 118/118 [==============================] - 2s 19ms/step - loss: 0.4047 - accuracy: 0.9611 - val_loss: 0.4009 - val_accuracy: 0.9596
# Epoch 41/50
# 118/118 [==============================] - 2s 19ms/step - loss: 0.4003 - accuracy: 0.9622 - val_loss: 0.3917 - val_accuracy: 0.9635
# Epoch 42/50
# 118/118 [==============================] - 2s 19ms/step - loss: 0.3985 - accuracy: 0.9621 - val_loss: 0.4057 - val_accuracy: 0.9592
# Epoch 43/50
# 118/118 [==============================] - 2s 19ms/step - loss: 0.3958 - accuracy: 0.9623 - val_loss: 0.3955 - val_accuracy: 0.9616
# Epoch 44/50
# 118/118 [==============================] - 2s 19ms/step - loss: 0.3942 - accuracy: 0.9621 - val_loss: 0.4081 - val_accuracy: 0.9540
# Epoch 45/50
# 118/118 [==============================] - 2s 19ms/step - loss: 0.3926 - accuracy: 0.9616 - val_loss: 0.3871 - val_accuracy: 0.9616
# Epoch 46/50
# 118/118 [==============================] - 2s 19ms/step - loss: 0.3924 - accuracy: 0.9622 - val_loss: 0.3995 - val_accuracy: 0.9603
# Epoch 47/50
# 118/118 [==============================] - 2s 19ms/step - loss: 0.3911 - accuracy: 0.9615 - val_loss: 0.3876 - val_accuracy: 0.9614
# Epoch 48/50
# 118/118 [==============================] - 2s 19ms/step - loss: 0.3844 - accuracy: 0.9635 - val_loss: 0.3874 - val_accuracy: 0.9614
# Epoch 49/50
# 118/118 [==============================] - 2s 18ms/step - loss: 0.3816 - accuracy: 0.9637 - val_loss: 0.4023 - val_accuracy: 0.9542
# Epoch 50/50
# 118/118 [==============================] - 2s 19ms/step - loss: 0.3829 - accuracy: 0.9638 - val_loss: 0.3852 - val_accuracy: 0.9626

# %% [markdown]
# ### Evaluación del modelo con regularización L2

# %%
plot_curves(hist.history)

# %% [markdown]
# ### Visualización de los pesos

# %%
plot_weights(model_with_l2)
plot_weights_hist(model_with_l2)

# %% [markdown]
# ## Regularización del modelo con Dropout
# Ahora crea el mismo modelo pero añade dropout. Prueba distintos valores de dropout.

# %%
tf.keras.backend.clear_session()
tf.random.set_seed(0)
# Crear modelo
n_epochs = 25
model_with_dp=tf.keras.Sequential()
model_with_dp.add(tf.keras.layers.Dense(256, input_shape=(784,),activation='relu'))
model_with_dp.add(tf.keras.layers.Dropout(0.35))
model_with_dp.add(tf.keras.layers.Dense(128,activation='relu'))
model_with_dp.add(tf.keras.layers.Dropout(0.35))
model_with_dp.add(tf.keras.layers.Dense(64,activation='relu'))
model_with_dp.add(tf.keras.layers.Dropout(0.35))
model_with_dp.add(tf.keras.layers.Dense(32,activation='relu'))
model_with_dp.add(tf.keras.layers.Dropout(0.35))
model_with_dp.add(tf.keras.layers.Dense(10,activation='softmax'))

# Compilamos el modelo
model_with_dp.compile(loss='sparse_categorical_crossentropy',
                      optimizer=optimizer,
                      metrics=['accuracy'])

# Entrenamos
hist = model_with_dp.fit(X_train, 
                         y_train, 
                         batch_size=batch_size, 
                         epochs=n_epochs,
                         verbose=1, 
                         shuffle=True, 
                         validation_data=(X_test, y_test))
# Out:
# Epoch 1/25
# 118/118 [==============================] - 3s 22ms/step - loss: 0.7483 - accuracy: 0.7701 - val_loss: 0.1896 - val_accuracy: 0.9477
# Epoch 2/25
# 118/118 [==============================] - 2s 21ms/step - loss: 0.3060 - accuracy: 0.9241 - val_loss: 0.1473 - val_accuracy: 0.9610
# Epoch 3/25
# 118/118 [==============================] - 3s 21ms/step - loss: 0.2443 - accuracy: 0.9414 - val_loss: 0.1323 - val_accuracy: 0.9633
# Epoch 4/25
# 118/118 [==============================] - 2s 21ms/step - loss: 0.2140 - accuracy: 0.9481 - val_loss: 0.1280 - val_accuracy: 0.9664
# Epoch 5/25
# 118/118 [==============================] - 2s 21ms/step - loss: 0.1926 - accuracy: 0.9541 - val_loss: 0.1191 - val_accuracy: 0.9697
# Epoch 6/25
# 118/118 [==============================] - 2s 21ms/step - loss: 0.1742 - accuracy: 0.9583 - val_loss: 0.1168 - val_accuracy: 0.9718
# Epoch 7/25
# 118/118 [==============================] - 2s 21ms/step - loss: 0.1630 - accuracy: 0.9608 - val_loss: 0.1065 - val_accuracy: 0.9735
# Epoch 8/25
# 118/118 [==============================] - 2s 21ms/step - loss: 0.1498 - accuracy: 0.9640 - val_loss: 0.1085 - val_accuracy: 0.9727
# Epoch 9/25
# 118/118 [==============================] - 3s 22ms/step - loss: 0.1432 - accuracy: 0.9652 - val_loss: 0.1003 - val_accuracy: 0.9764
# Epoch 10/25
# 118/118 [==============================] - 3s 21ms/step - loss: 0.1321 - accuracy: 0.9683 - val_loss: 0.1020 - val_accuracy: 0.9765
# Epoch 11/25
# 118/118 [==============================] - 3s 22ms/step - loss: 0.1280 - accuracy: 0.9690 - val_loss: 0.1096 - val_accuracy: 0.9738
# Epoch 12/25
# 118/118 [==============================] - 2s 21ms/step - loss: 0.1198 - accuracy: 0.9710 - val_loss: 0.1024 - val_accuracy: 0.9770
# Epoch 13/25
# 118/118 [==============================] - 2s 21ms/step - loss: 0.1143 - accuracy: 0.9717 - val_loss: 0.0973 - val_accuracy: 0.9781
# Epoch 14/25
# 118/118 [==============================] - 2s 21ms/step - loss: 0.1115 - accuracy: 0.9728 - val_loss: 0.0937 - val_accuracy: 0.9785
# Epoch 15/25
# 118/118 [==============================] - 2s 21ms/step - loss: 0.1051 - accuracy: 0.9741 - val_loss: 0.1021 - val_accuracy: 0.9773
# Epoch 16/25
# 118/118 [==============================] - 2s 21ms/step - loss: 0.1072 - accuracy: 0.9740 - val_loss: 0.0976 - val_accuracy: 0.9790
# Epoch 17/25
# 118/118 [==============================] - 2s 21ms/step - loss: 0.1018 - accuracy: 0.9750 - val_loss: 0.1027 - val_accuracy: 0.9783
# Epoch 18/25
# 118/118 [==============================] - 2s 21ms/step - loss: 0.0961 - accuracy: 0.9761 - val_loss: 0.0983 - val_accuracy: 0.9795
# Epoch 19/25
# 118/118 [==============================] - 3s 21ms/step - loss: 0.0983 - accuracy: 0.9761 - val_loss: 0.0931 - val_accuracy: 0.9792
# Epoch 20/25
# 118/118 [==============================] - 2s 21ms/step - loss: 0.0916 - accuracy: 0.9782 - val_loss: 0.0996 - val_accuracy: 0.9789
# Epoch 21/25
# 118/118 [==============================] - 2s 21ms/step - loss: 0.0909 - accuracy: 0.9779 - val_loss: 0.1027 - val_accuracy: 0.9786
# Epoch 22/25
# 118/118 [==============================] - 3s 21ms/step - loss: 0.0857 - accuracy: 0.9799 - val_loss: 0.0992 - val_accuracy: 0.9777
# Epoch 23/25
# 118/118 [==============================] - 2s 21ms/step - loss: 0.0856 - accuracy: 0.9784 - val_loss: 0.1074 - val_accuracy: 0.9775
# Epoch 24/25
# 118/118 [==============================] - 2s 21ms/step - loss: 0.0876 - accuracy: 0.9788 - val_loss: 0.0973 - val_accuracy: 0.9797
# Epoch 25/25
# 118/118 [==============================] - 2s 21ms/step - loss: 0.0829 - accuracy: 0.9799 - val_loss: 0.0896 - val_accuracy: 0.9810

# %% [markdown]
# ### Evaluación del modelo con Dropout

# %%
# Plots
plot_curves(hist.history)
# plot_weights(model_with_dp)
plot_weights_hist(model_with_dp)
